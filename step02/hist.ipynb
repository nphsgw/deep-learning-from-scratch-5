# %%
import os
import numpy as np
import matplotlib.pyplot as plt

path = './height.txt'
xs = np.loadtxt(path)
print(xs.shape)

plt.hist(xs, bins='auto', density=True)
plt.xlabel('Height(cm)')
plt.ylabel('Probability Density')
plt.show()
# Out:
# (25000,)

# %% [markdown]
# データセットの身長は正規分布になりそう。推定する確率分布が正規分布だと仮定する。
